# %% [markdown]
# # Creating new workflows and application bindings
#
# This recipe shows how create new application bindings to create new workflows.
#
# `ete-build` comes with a number of pre-configured applications, which are meant to cover default options of the supported software and some common approaches. Here you will learn how to create custom configurations that you can use in workflows.
#
#
# ## Requirements
# - ete3
# - ete3_external_apps
# - [basic concepts about ete-build](ete_build_basics.ipynb)
# - [composing custom workflows](ete_build_workflows.ipynb)

# %% [markdown]
# ## Recipe
#
# ### 1. Configuring external software calls
#
# In [composing custom workflows](ete_build_workflows.ipynb), you learnt how to refer to the different preconfigured options in `ete-build`.
#
# You can explore the details of any application binding (or even workflow) by using the `ete3 build build show [blockname]`.

# %%
# %%bash
# ete3 build show raxml_default
# ete3 build show phyml_default
# ete3 build show mafft_linsi
# Out:
# [raxml_default]
#                               _desc = RAxML with default parameters, GAMMA JTT/GTR and aLRT branch supports.
#                                _app = raxml
#                          _bootstrap = alrt
#                             _method = GAMMA
#                           _aa_model = JTT
#                       _model_suffix =
#                                  -f = d
#                                  -p = 31416
#
# [phyml_default]
#                               _desc = Phyml tree using +G+I+F, 4 classes and aLRT branch supports. Default models JTT/GTR
#                                _app = phyml
#                           _aa_model = JTT
#                           _nt_model = GTR
#                   --no_memory_check =
#                             --quiet =
#                              --pinv = e
#                             --alpha = e
#                          --nclasses = 4
#                                  -o = tlr
#                                  -f = m
#                         --bootstrap = -2
#
# [mafft_linsi]
#                               _desc = mafft alignment using the L-INS-i mode
#                                _app = mafft
#                         --localpair =
#                        --maxiterate = 1000

# %% [markdown]
# As you have probably noticed, each application binding referred in workflow names is defined as a configuration block whose name is between brackets. To create new configuration blocks, you need to keep the following concepts in mind:
#
# - the name of the block should not contain other symbols rather than text, numbers and underscores. Never use hyphens.
# - Each block is composed of several internal `ete-build` options and several native software options.
#   - _internal options_ are always prepended by an underscore and they are used to define the software to execute, the description of the config block and some default parameters that should not be hardcoded as native program arguments.
#   - Any other option in the format "argument = value" are considered _native options_ and are passed as it to the corresponding software.
#   - To pass flags as arguments, you can use the syntax "`argument = ''`" or simply "`argument = `"

# %% [markdown]
# ### 2. Creating new configuration blocks
#
# Let's imagine that we want to create a new workflow where RAxML needs to be configured in a different manner.
#
# All we need to do is to dump any configuration block based on the RAxML bindings from the examples provided, and modify it. You can dump config blocks as regular text with the `ete2 build dump` command:

# %%
# %%bash
# ete3 build dump raxml_default > myconfig.cfg
# cat myconfig.cfg
# Out:
# [raxml_default]
#                                    _desc = RAxML with default parameters, GAMMA JTT/GTR and aLRT branch supports.
#                                     _app = raxml
#                               _bootstrap = alrt
#                                  _method = GAMMA
#                                _aa_model = JTT
#                            _model_suffix =
#                                       -f = d
#                                       -p = 31416

# %% [markdown]
# Let's now modify the options, so the configuration block looks like this (10 bootstraps and CAT model):
# ```
# [raxml_CAT_10]
#                          _desc = RAxML with default parameters, CAT with 100 bootstraps.
#                           _app = raxml
#                     _bootstrap = 10        # we will use 10 replicates to keep the example fast
#                        _method = CAT
#                      _aa_model = JTT
#                  _model_suffix =
#                             -f = d
#                             -p = 31416
# ```

# %%
# %%bash
# echo '
# [raxml_CAT_10]
#                          _desc = RAxML with default parameters, CAT with 100 bootstraps.
#                           _app = raxml
#                     _bootstrap = 10
#                        _method = CAT
#                      _aa_model = JTT
#                  _model_suffix =
#                             -f = d
#                             -p = 31416
# ' > myconfig.cfg
# cat myconfig.cfg
# Out:
# [raxml_CAT_10]
#                          _desc = RAxML with default parameters, CAT with 100 bootstraps.
#                           _app = raxml
#                     _bootstrap = 10
#                        _method = CAT
#                      _aa_model = JTT
#                  _model_suffix =
#                             -f = d
#                             -p = 31416

# %% [markdown]
# ### 3. Using our custom configuration blocks
#
# Once you have create all your personal configuration blocks, you can used them to run custom workflows by passing your configuration file with the `'-c'` option of `ete-build`
#
# Note that for this example we also are enabling 5 CPUs, you can adjust this parameter to your system.

# %%
# %%bash
# ete3 build -a data/NUP62.aa.fa --clearall -o raxml_cat/ -w mafft_linsi-none-none-raxml_CAT_10 -c myconfig.cfg --cpu 5
# Out:
# Toolchain path: /Users/jhc/anaconda/bin/ete3_apps
# Toolchain version: 2.0.3
#
#
#       --------------------------------------------------------------------------------
#                   ETE build - reproducible phylogenetic workflows
#                                     unknown, unknown.
#
#       If you use ETE in a published work, please cite:
#
#         Jaime Huerta-Cepas, Joaquín Dopazo and Toni Gabaldón. ETE: a python
#         Environment for Tree Exploration. BMC Bioinformatics 2010,
#         11:24. doi:10.1186/1471-2105-11-24
#
#       (Note that a list of the external programs used to complete all necessary
#       computations will be also shown after execution. Those programs should
#       also be cited.)
#       --------------------------------------------------------------------------------
#
#
# INFO -  Testing x86-64  portable applications...
#        clustalo: OK - 1.2.1
# Dialign-tx not supported in OS X
#        fasttree: OK - FastTree Version 2.1.8 Double precision (No SSE3), OpenMP (2 threads)
#          kalign: OK - Kalign version 2.04, Copyright (C) 2004, 2005, 2006 Timo Lassmann
#           mafft: OK - MAFFT v6.861b (2011/09/24)
#          muscle: OK - MUSCLE v3.8.31 by Robert C. Edgar
#           phyml: OK - . This is PhyML version 20160115.
#      pmodeltest: OK - pmodeltest.py v1.4
#           prank: OK - prank v.100802. Minimal usage: 'prank sequence_file'
#        probcons: OK - PROBCONS version 1.12 - align multiple protein sequences and print to standard output
#           raxml: OK - This is RAxML version 8.1.20 released by Alexandros Stamatakis on April 18 2015.
#  raxml-pthreads: OK - This is RAxML version 8.1.20 released by Alexandros Stamatakis on April 18 2015.
#          readal: OK - readAl v1.4.rev6 build[2012-02-02]
#          statal: OK - statAl v1.4.rev6 build[2012-02-02]
#         tcoffee: OK - PROGRAM: T-COFFEE Version_11.00.8cbe486 (2014-08-12 22:05:29 - Revision 8cbe486 - Build 477)
#          trimal: OK - trimAl v1.4.rev6 build[2012-02-02]
# INFO -  Starting ETE-build execution at Sun Feb  7 09:10:51 2016
# INFO -  Output directory /Users/jhc/_Devel/cookbook/recipes/raxml_cat
# INFO -  Erasing all existing npr data...
# WRNG -  Using existing dir: /Users/jhc/_Devel/cookbook/recipes/raxml_cat/db
# INFO -  Reading aa sequences from data/NUP62.aa.fa...
# WRNG -  25 target sequences
# INFO -  ETE build starts now!
# INFO -   Updating tasks status: (Sun Feb  7 09:10:51 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) MultiSeqTask (25 aa seqs, MSF, /mafft_lins...xml_CAT_10)
# INFO -   (D) MultiSeqTask (25 aa seqs, MSF, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:10:53 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) AlgTask (25 aa seqs, Mafft, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:10:55 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) AlgTask (25 aa seqs, Mafft, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:10:57 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) AlgTask (25 aa seqs, Mafft, /mafft_lins...xml_CAT_10)
# INFO -   (D) AlgTask (25 aa seqs, Mafft, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:10:59 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:01 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:03 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (Q) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:05 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:07 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:09 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:11 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:13 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:15 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:17 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:19 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:21 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:23 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:25 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:27 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:29 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:31 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:33 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:35 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:37 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:39 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:41 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:43 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:45 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:47 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:49 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:51 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:53 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:55 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:57 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:11:59 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:01 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:03 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:05 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:07 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:09 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:11 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:13 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:15 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:17 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:19 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:21 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:23 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:25 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:27 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:29 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:31 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:33 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:35 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:37 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:39 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:41 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:43 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:45 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:47 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:49 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:51 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:53 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:55 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:57 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:12:59 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:01 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:03 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:05 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:07 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:09 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:11 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:13 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (R) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:15 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:17 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (Q) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -   (D) TreeTask (25 aa seqs, RaxML, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Feb  7 09:13:19 2016)
# INFO -  Thread mafft_linsi-none-none-raxml_CAT_10: pending tasks: 1 of sizes: 25
# INFO -   (W) TreeMergeTask (25 aa seqs, TreeMerger, /mafft_lins...xml_CAT_10)
# INFO -   (D) TreeMergeTask (25 aa seqs, TreeMerger, /mafft_lins...xml_CAT_10)
# INFO -  Waiting 2 seconds
# INFO -  Assembling final tree...
# INFO -  Done thread mafft_linsi-none-none-raxml_CAT_10 in 1 iteration(s)
# INFO -  Writing final tree for mafft_linsi-none-none-raxml_CAT_10
#    /Users/jhc/_Devel/cookbook/recipes/raxml_cat/mafft_linsi-none-none-raxml_CAT_10/NUP62.aa.fa.final_tree.nw
#    /Users/jhc/_Devel/cookbook/recipes/raxml_cat/mafft_linsi-none-none-raxml_CAT_10/NUP62.aa.fa.final_tree.nwx (newick extended)
# INFO -  Writing final tree alignment mafft_linsi-none-none-raxml_CAT_10
#    /Users/jhc/_Devel/cookbook/recipes/raxml_cat/mafft_linsi-none-none-raxml_CAT_10/NUP62.aa.fa.final_tree.used_alg.fa
# INFO -  Writing root node alignment mafft_linsi-none-none-raxml_CAT_10
#    /Users/jhc/_Devel/cookbook/recipes/raxml_cat/mafft_linsi-none-none-raxml_CAT_10/NUP62.aa.fa.final_tree.fa
# INFO -  Generating tree image for mafft_linsi-none-none-raxml_CAT_10
#    /Users/jhc/_Devel/cookbook/recipes/raxml_cat/mafft_linsi-none-none-raxml_CAT_10/NUP62.aa.fa.final_tree.png
# INFO -  Done
# INFO -  Deleting temporal data...
#    ========================================================================
#          The following published software and/or methods were used.
#                *** Please, do not forget to cite them! ***
#    ========================================================================
#    Huerta-Cepas J, Dopazo J, Gabaldón T. ETE: a python Environment for Tree
#       Exploration. BMC Bioinformatics. 2010 Jan 13;11:24.
#    Katoh K, Kuma K, Toh H, Miyata T. MAFFT version 5: improvement in
#       accuracy of multiple sequence alignment. Nucleic Acids Res. 2005 Jan
#       20;33(2):511-8.
#    Stamatakis A. RAxML version 8: a tool for phylogenetic analysis and
#       post-analysis of large phylogenies Bioinformatics (2014) 30 (9):
#       1312-1313.

# %% [markdown]
# After a few minutes a tree based on 10 RAxML bootstrap replicates using CAT should be ready. You can now load and analyze the tree.

# %%
from ete3 import Tree
cat_tree = Tree("raxml_cat/mafft_linsi-none-none-raxml_CAT_10/NUP62.aa.fa.final_tree.nw")
print cat_tree.get_ascii(attributes=["support", "name"])
# Out:
#           /-1.0, Phy004OQ34_STRCA
#      /1.0,
#     |    |     /-1.0, Phy004PA1B_ANAPL
#     |     \1.0,
#     |         |     /-1.0, Phy0054BO3_MELGA
#     |          \1.0,
#     |               \-1.0, Phy003I7ZJ_CHICK
#     |
#     |               /-1.0, Phy00508FR_NIPNI
# -1.0,          /0.3,
#     |         |     \-1.0, Phy0050IUO_OPIHO
#     |     /0.1,
#     |    |    |     /-1.0, Phy004Y35P_HALLE
#     |    |     \1.0,
#     |    |          \-1.0, Phy004XRVA_HALAL
#     |    |
#     |    |          /-1.0, Phy004W8WJ_FALPE
#     |    |     /0.9,
#      \1.0,    |     \-1.0, Phy004W8WI_FALPE
#          |    |
#          |    |                         /-1.0, Phy004OLZM_COLLI
#          |    |                    /0.9,
#          |    |                   |     \-1.0, Phy004OLZN_COLLI
#          |    |               /0.3,
#          |    |              |    |     /-1.0, Phy004V34S_CORBR
#          |    |              |     \0.4,
#           \0.0,          /0.1,          \-1.0, Phy004Y9VQ_LEPDC
#               |         |    |
#               |         |    |     /-1.0, Phy004VACL_55661
#               |         |     \0.4,
#               |     /0.0,          \-1.0, Phy004U0LB_BUCRH
#               |    |    |
#               |    |    |          /-1.0, Phy004Z7RR_MERNU
#               |    |    |     /0.2,
#               |    |    |    |     \-1.0, Phy004TLNA_APAVI
#               |    |     \0.0,
#                \0.0,         |     /-1.0, Phy00527O5_PICPB
#                    |          \0.3,
#                    |               \-1.0, Phy004Z0OU_MELUD
#                    |
#                    |     /-1.0, Phy004STVX_187382
#                    |    |
#                     \0.1,          /-1.0, Phy00535AU_PYGAD
#                         |     /0.9,
#                         |    |     \-1.0, Phy004O1E0_APTFO
#                          \0.3,
#                              |     /-1.0, Phy004UIZ8_CALAN
#                               \0.2,
#                                    \-1.0, Phy004SNJQ_CHAVO
